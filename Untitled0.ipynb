# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardarthur0123-netizen/foundation-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y = 2
x =3
y =x+1
print (y)
# Out:
# 4

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
for i in range(1, 58):
    print(f"I have {i} iterations")
# Out:
# I have 1 iterations
# I have 2 iterations
# I have 3 iterations
# I have 4 iterations
# I have 5 iterations
# I have 6 iterations
# I have 7 iterations
# I have 8 iterations
# I have 9 iterations
# I have 10 iterations
# I have 11 iterations
# I have 12 iterations
# I have 13 iterations
# I have 14 iterations
# I have 15 iterations
# I have 16 iterations
# I have 17 iterations
# I have 18 iterations
# I have 19 iterations
# I have 20 iterations
# I have 21 iterations
# I have 22 iterations
# I have 23 iterations
# I have 24 iterations
# I have 25 iterations
# I have 26 iterations
# I have 27 iterations
# I have 28 iterations
# I have 29 iterations
# I have 30 iterations
# I have 31 iterations
# I have 32 iterations
# I have 33 iterations
# I have 34 iterations
# I have 35 iterations
# I have 36 iterations
# I have 37 iterations
# I have 38 iterations
# I have 39 iterations
# I have 40 iterations
# I have 41 iterations
# I have 42 iterations
# I have 43 iterations
# ...

# %%
def fibonacci (x,y):
  return x+y

h = 0
for i in range(1,20):
  h = fibonacci(h,i)
  print (f"h  {h} - -i{i}")
# Out:
# h  1 - -i1
# h  3 - -i2
# h  6 - -i3
# h  10 - -i4
# h  15 - -i5
# h  21 - -i6
# h  28 - -i7
# h  36 - -i8
# h  45 - -i9
# h  55 - -i10
# h  66 - -i11
# h  78 - -i12
# h  91 - -i13
# h  105 - -i14
# h  120 - -i15
# h  136 - -i16
# h  153 - -i17
# h  171 - -i18
# h  190 - -i19

# %%
def fibonacci (x,y):
  return x+y
  h = 0
  j = 1
  for i in range(1,30):
    j0 = j
    l = 0
    print (f"BEFORE h: {h}; j: {j}; j0:{j0}")
    j = fibonacci(h,j)
    h = j0
    print (f"AFTER h: {h}; j: {j}; j0:{j0}")
    #print (h)

# %%
x= 2
y = 3
z = 4
while z > y:
  z = z-1
  y = z
  print (y)
# Out:
# 3

# %% [markdown]
# print the frist 20 elements of fibonacci sequence

# %% [markdown]
# create a list with numbers between 35 and 50

# %%
tech_list = []
i = 41
while i <= 49:
  tech_list.append(i)
  i += 1
print (tech_list)
# Out:
# [41, 42, 43, 44, 45, 46, 47, 48, 49]
